# %%
import pandas as pd
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
train, val = train_test_split((train_df['Image_iD'], train_df['category']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Image_ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-8800e643a02e> in <module>
# ...

# %%
image_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e60375206710> in <module>
# ----> 1 image_id
#
# NameError: name 'image_id' is not defined

# %%
train_df = pd.read_csv('../../Downloads/Kaggle_Runs/HE_Challenge_data/train.csv')

# %%
train_df
# Out:
#        image_id  category
# 0             0        77
# 1             1        81
# 2             2        52
# 3             3        72
# 4             4        58
# 5             5         2
# 6             6        75
# 7             7        67
# 8             8        51
# 9             9        15
# 10           10        77
# 11           11        15
# 12           12        75
# 13           13        52
# 14           14        58
# 15           15         9
# 16           16        77
# 17           17        81
# 18           18        86
# 19           19         2
# 20           20        97
# 21           21        39
# 22           22        51
# 23           23         4
# 24           24        65
# 25           25         4
# 26           26        75
# 27           27        65
# 28           28        51
# 29           29         9
# ...         ...       ...
# 18510     18510        57
# 18511     18511        42
# 18512     18512        79
# ...

# %%
(train_df.category.unique())
# Out:
# array([ 77,  81,  52,  72,  58,   2,  75,  67,  51,  15,   9,  86,  97,
#         39,   4,  65, 100,  63,  56,  19,  57,  41,  12,  25,  95,  60,
#         87,  47,  54,  82,  62,  70,  83,  73,  37,  74,  24,  20,  85,
#         11,  40,  76,  46,   1, 102,  69,  35,  94,  28,  29,  93,  78,
#         34,  21,  88,  36,  49,  44,  10,  80,  59,  23,  50,  96,  90,
#          8,  42,  99,  89,  68,  55,   3,  45,  30,  66,  71,  18,  84,
#         33,  32,  38, 101,   5,  98,  16,  22,  43,  53,   7,  64,  27,
#         92,  17,  79,  48,  14,  91,  31,  61,  13,  26,   6])

# %%
18540*.20, 18540-3708
# Out:
# (3708.0, 14832)

# %%
18540*0.30, 18540-5562
# Out:
# (5562.0, 12978)

# %%
pd.options.display.max_rows = 102

# %%
train_df.category.value_counts()
# Out:
# 51     582
# 77     567
# 46     441
# 73     438
# 89     414
# 74     387
# 81     375
# 94     366
# 88     348
# 78     309
# 83     297
# 43     294
# 41     288
# 95     288
# 75     270
# 58     258
# 82     252
# 60     246
# 56     246
# 76     243
# 37     243
# 80     237
# 65     231
# 72     216
# 53     210
# 44     210
# 23     207
# 96     207
# 50     207
# 12     198
# 11     198
# 84     195
# 30     192
# 52     192
# 8      192
# 17     192
# 90     186
# 18     186
# 98     186
# 29     177
# 71     177
# 91     171
# 36     171
# 48     162
# 55     162
# 40     153
# 57     153
# 59     153
# 47     153
# 97     150
# 92     150
# 28     150
# 5      147
# 85     144
# 87     144
# 99     144
# 70     141
# 66     138
# 54     138
# 2      135
# 42     135
# 22     135
# 101    132
# 86     132
# 38     126
# 62     126
# 20     126
# 4      126
# 69     123
# 63     123
# 68     123
# 31     117
# 64     117
# 61     114
# 19     111
# 15     111
# ...

# %%
class_df = pd.DataFrame(train_df.category.value_counts())

# %%
class_df.head()
# Out:
#     category
# 51       582
# 77       567
# 46       441
# 73       438
# 89       414

# %%
class_df.reset_index(inplace=True)

# %%
class_df.head()
# Out:
#    index  category
# 0     51       582
# 1     77       567
# 2     46       441
# 3     73       438
# 4     89       414

# %%
class_df.columns = ['Class', 'Count']

# %%
class_df
# Out:
#      Class  Count
# 0       51    582
# 1       77    567
# 2       46    441
# 3       73    438
# 4       89    414
# 5       74    387
# 6       81    375
# 7       94    366
# 8       88    348
# 9       78    309
# 10      83    297
# 11      43    294
# 12      41    288
# 13      95    288
# 14      75    270
# 15      58    258
# 16      82    252
# 17      60    246
# 18      56    246
# 19      76    243
# 20      37    243
# 21      80    237
# 22      65    231
# 23      72    216
# 24      53    210
# 25      44    210
# 26      23    207
# 27      96    207
# 28      50    207
# 29      12    198
# 30      11    198
# 31      84    195
# 32      30    192
# 33      52    192
# 34       8    192
# 35      17    192
# 36      90    186
# 37      18    186
# 38      98    186
# 39      29    177
# 40      71    177
# 41      91    171
# 42      36    171
# 43      48    162
# 44      55    162
# 45      40    153
# 46      57    153
# 47      59    153
# 48      47    153
# ...

# %%
class_df.head()

# %%
class_df.iloc[0].Class
# Out:
# 51

# %%
ten_per = {}
for idx, count in enumerate(class_df['Count']):
    ten_per[class_df.iloc[idx].Class] = max(int(count*.20), 20)
# Out:
# 582
# 567
# 441
# 438
# 414
# 387
# 375
# 366
# 348
# 309
# 297
# 294
# 288
# 288
# 270
# 258
# 252
# 246
# 246
# 243
# 243
# 237
# 231
# 216
# 210
# 210
# 207
# 207
# 207
# 198
# 198
# 195
# 192
# 192
# 192
# 192
# 186
# 186
# 186
# 177
# 177
# 171
# 171
# 162
# 162
# 153
# 153
# 153
# 153
# 150
# 150
# 150
# 147
# 144
# 144
# 144
# 141
# 138
# 138
# 135
# 135
# 135
# 132
# 132
# 126
# 126
# 126
# 126
# 123
# 123
# 123
# 117
# 117
# 114
# 111
# 111
# 111
# 111
# 111
# 108
# 108
# 105
# 105
# 105
# 102
# 102
# 102
# 99
# 96
# 96
# 93
# 93
# 93
# 93
# 93
# 90
# 90
# 90
# 90
# 90
# 90
# 90

# %%
ten_per
# Out:
# {51: 116,
#  77: 113,
#  46: 88,
#  73: 87,
#  89: 82,
#  74: 77,
#  81: 75,
#  94: 73,
#  88: 69,
#  78: 61,
#  83: 59,
#  43: 58,
#  41: 57,
#  95: 57,
#  75: 54,
#  58: 51,
#  82: 50,
#  60: 49,
#  56: 49,
#  76: 48,
#  37: 48,
#  80: 47,
#  65: 46,
#  72: 43,
#  53: 42,
#  44: 42,
#  23: 41,
#  96: 41,
#  50: 41,
#  12: 39,
#  11: 39,
#  84: 39,
#  30: 38,
#  52: 38,
#  8: 38,
#  17: 38,
#  90: 37,
#  18: 37,
#  98: 37,
#  29: 35,
#  71: 35,
#  91: 34,
#  36: 34,
#  48: 32,
#  55: 32,
#  40: 30,
#  57: 30,
#  59: 30,
#  47: 30,
#  97: 30,
#  92: 30,
#  28: 30,
#  5: 29,
#  85: 28,
#  87: 28,
#  99: 28,
#  70: 28,
#  66: 27,
#  54: 27,
#  2: 27,
#  42: 27,
#  22: 27,
#  101: 26,
#  86: 26,
#  38: 25,
#  62: 25,
#  20: 25,
#  4: 25,
#  69: 24,
#  63: 24,
#  68: 24,
#  31: 23,
#  64: 23,
#  61: 22,
#  19: 22,
#  15: 22,
#  49: 22,
#  100: 22,
#  13: 22,
#  14: 21,
#  102: 21,
#  93: 21,
#  9: 21,
#  33: 21,
#  32: 20,
#  6: 20,
#  10: 20,
#  35: 20,
#  67: 20,
#  24: 20,
#  39: 20,
# ...

# %%
sum(ten_per.values())
# Out:
# 3699

# %%
min(class_df['Count'])
# Out:
# 90

# %%
ten_per
# Out:
# {51: 116,
#  77: 113,
#  46: 88,
#  73: 87,
#  89: 82,
#  74: 77,
#  81: 75,
#  94: 73,
#  88: 69,
#  78: 61,
#  83: 59,
#  43: 58,
#  41: 57,
#  95: 57,
#  75: 54,
#  58: 51,
#  82: 50,
#  60: 49,
#  56: 49,
#  76: 48,
#  37: 48,
#  80: 47,
#  65: 46,
#  72: 43,
#  53: 42,
#  44: 42,
#  23: 41,
#  96: 41,
#  50: 41,
#  12: 39,
#  11: 39,
#  84: 39,
#  30: 38,
#  52: 38,
#  8: 38,
#  17: 38,
#  90: 37,
#  18: 37,
#  98: 37,
#  29: 35,
#  71: 35,
#  91: 34,
#  36: 34,
#  48: 32,
#  55: 32,
#  40: 30,
#  57: 30,
#  59: 30,
#  47: 30,
#  97: 30,
#  92: 30,
#  28: 30,
#  5: 29,
#  85: 28,
#  87: 28,
#  99: 28,
#  70: 28,
#  66: 27,
#  54: 27,
#  2: 27,
#  42: 27,
#  22: 27,
#  101: 26,
#  86: 26,
#  38: 25,
#  62: 25,
#  20: 25,
#  4: 25,
#  69: 24,
#  63: 24,
#  68: 24,
#  31: 23,
#  64: 23,
#  61: 22,
#  19: 22,
#  15: 22,
#  49: 22,
#  100: 22,
#  13: 22,
#  14: 21,
#  102: 21,
#  93: 21,
#  9: 21,
#  33: 21,
#  32: 20,
#  6: 20,
#  10: 20,
#  35: 20,
#  67: 20,
#  24: 20,
#  39: 20,
# ...

# %% [markdown]
# # Taking random indices from Classes for random 20%

# %%
import numpy as np

# %%
train_df
# Out:
#        image_id  category
# 0             0        77
# 1             1        81
# 2             2        52
# 3             3        72
# 4             4        58
# 5             5         2
# 6             6        75
# 7             7        67
# 8             8        51
# 9             9        15
# 10           10        77
# 11           11        15
# 12           12        75
# 13           13        52
# 14           14        58
# 15           15         9
# 16           16        77
# 17           17        81
# 18           18        86
# 19           19         2
# 20           20        97
# 21           21        39
# 22           22        51
# 23           23         4
# 24           24        65
# 25           25         4
# 26           26        75
# 27           27        65
# 28           28        51
# 29           29         9
# 30           30        97
# 31           31        86
# 32           32         2
# 33           33       100
# ...

# %%
train_cat = train_df.sort_values(by='category')

# %%
train_cat['category']
# Out:
#        image_id  category
# 827         827         1
# 12348     12348         1
# 4727       4727         1
# 631         631         1
# 4720       4720         1
# 9529       9529         1
# 8463       8463         1
# 5520       5520         1
# 11618     11618         1
# 12249     12249         1
# 6707       6707         1
# 14326     14326         1
# 608         608         1
# 11065     11065         1
# 7292       7292         1
# 6211       6211         1
# 6763       6763         1
# 15943     15943         1
# 8485       8485         1
# 5512       5512         1
# 5130       5130         1
# 10609     10609         1
# 18160     18160         1
# 100         100         1
# 6053       6053         1
# 1338       1338         1
# 1336       1336         1
# 16224     16224         1
# 6059       6059         1
# 18031     18031         1
# 4908       4908         1
# 12536     12536         1
# 6836       6836         1
# 8796       8796         1
# ...

# %%
import numpy as np

# %%
np.random.seed(42)
np.random.permutation(10)
# Out:
# array([8, 1, 5, 0, 7, 2, 9, 4, 3, 6])
