# %%
import warnings
warnings.filterwarnings('ignore')

import os
import gc
import joblib
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics, preprocessing
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model,load_model
from tensorflow.keras import callbacks
from tensorflow.keras import backend as K
from tensorflow.keras import utils

# %%
def auc(y_true, y_pred):
    def fallback_auc(y_true, y_pred):
        try:
#             return metrics.roc_auc_score(y_true, y_pred)
            return metrics.f1_score(y_true, y_pred)
        except:
            return 0.5
    return tf.py_function(fallback_auc, (y_true, y_pred), tf.double)
#     return metrics.roc_auc_score(y_true, y_pred)

# %%
def create_model(data, catcols):
    inputs = []
    outputs = []
    for c in catcols:
        num_unique_values = int(data[c].nunique())
        embed_dim = int(min(np.ceil((num_unique_values)/2), 50))
        inp = layers.Input(shape=(1,))
        out = layers.Embedding(num_unique_values+1, embed_dim, name=c)(inp)
        out = layers.SpatialDropout1D(0.3)(out)
        out = layers.Reshape(target_shape=(embed_dim, ))(out)
        inputs.append(inp)
        outputs.append(out)
        
    x = layers.Concatenate()(outputs)
    x = layers.BatchNormalization()(x)
    
    x = layers.Dense(300, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Dense(300, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)

    y = layers.Dense(4, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=y)
    
    return model

# %%
# experiment
model = create_model(data, features)
model

# %%
model.summary()

# %%
data_dir = '/home/anubhav/Downloads/Kaggle_Runs/HackerEarth_Airplane/'

# %%
pd.set_option('display.max_columns', 30)

# %%
train = pd.read_csv(f'{data_dir}train.csv')
test = pd.read_csv(f'{data_dir}test.csv')
sample = pd.read_csv(f'{data_dir}sample_submission.csv')

# %%
train.Severity.unique()
# Out:
# array(['Minor_Damage_And_Injuries', 'Significant_Damage_And_Fatalities',
#        'Significant_Damage_And_Serious_Injuries',
#        'Highly_Fatal_And_Damaging'], dtype=object)

# %%
train.Severity.replace(to_replace = ['Minor_Damage_And_Injuries', 'Significant_Damage_And_Fatalities',
                                     'Significant_Damage_And_Serious_Injuries','Highly_Fatal_And_Damaging'],
                       value = [0, 1, 2, 3], inplace = True)

# test.Severity.replace(to_replace = ['Minor_Damage_And_Injuries', 'Significant_Damage_And_Fatalities',
#                                      'Significant_Damage_And_Serious_Injuries','Highly_Fatal_And_Damaging'],
#                        value = [0, 1, 2, 3], inplace = True)

# %% [markdown]
# ## A Bit of EDA

# %%
train.head()

# %%
train['Severity'].unique()

# %%
len(train)

# %%
train['Total_Safety_Complaints'].nunique()

# %%
len(sample) == len(test)

# %% [markdown]
# ## Back to training loop

# %%
test.head()
# Out:
#    Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0     19.497717                     16                        6
# 1     58.173516                     15                        3
# 2     33.287671                     15                        3
# 3      3.287671                     21                        5
# 4     10.867580                     18                        2
#
#    Control_Metric  Turbulence_In_gforces  Cabin_Temperature  \
# 0       72.151322               0.388959              78.32
# 1       64.585232               0.250841              78.60
# 2       64.721969               0.336669              86.96
# 3       66.362808               0.421775              80.86
# 4       56.107566               0.313228              79.22
#
#    Accident_Type_Code  Max_Elevation  Violations  Adverse_Weather_Metric  \
# 0                   4   37949.724386           2                0.069692
# 1                   7   30194.805567           2                0.002777
# 2                   6   17572.925484           1                0.004316
# 3                   3   40209.186341           2                0.199990
# 4                   2   35495.525408           2                0.483696
#
#    Accident_ID
# 0            1
# 1           10
# 2           14
# 3           17
# 4           21

# %%
test['Severity'] = -1
data = pd.concat([train, test]).reset_index(drop=True)

# features = [x for x in train.columns if x not in ['target']]
features = ['Days_Since_Inspection', 'Total_Safety_Complaints', 'Accident_Type_Code', 'Violations']
for feat in features:
    label_enc = preprocessing.LabelEncoder()
    data[feat] = label_enc.fit_transform(data[feat].fillna('-1').
                                         astype(str).values)

# %%
data
# Out:
#        Accident_ID  Accident_Type_Code  Adverse_Weather_Metric  \
# 0             7570                   1                0.424352
# 1            12128                   1                0.352350
# 2             2181                   6                0.003364
# 3             5946                   2                0.211728
# 4             9054                   2                0.176883
# 5            10947                   1                0.394505
# 6             4717                   3                0.058872
# 7             8008                   3                0.040419
# 8             8179                   1                0.619186
# 9             6324                   0                1.389295
# 10            3789                   1                0.424912
# 11            8946                   2                0.111873
# 12            3629                   2                0.222510
# 13            2451                   6                0.002567
# 14            4028                   2                0.095806
# 15           10493                   2                0.123761
# 16              20                   5                0.011242
# 17            2064                   3                0.066515
# 18            2765                   1                0.462514
# 19            2938                   1                0.159784
# 20           10309                   1                0.538862
# 21            3918                   1                0.508486
# 22            4830                   3                0.083992
# 23            6630                   0                1.664864
# 24           11434                   4                0.032437
# 25           10987                   5                0.010607
# 26            8830                   6                0.003022
# 27            2237                   3                0.048626
# 28            4196                   6                0.002916
# 29            4755                   2                0.194870
# ...            ...                 ...                     ...
# 12470        12366                   2                0.167541
# 12471        12367                   3                0.072860
# 12472        12378                   3                0.007273
# 12473        12389                   1                0.559007
# 12474        12390                   5                0.007208
# 12475        12402                   1                0.270945
# 12476        12406                   2                0.174810
# 12477        12412                   4                0.017656
# 12478        12413                   3                0.050881
# 12479        12415                   6                0.004934
# 12480        12420                   0                0.817157
# 12481        12423                   5                0.007901
# 12482        12432                   5                0.008928
# 12483        12433                   3                0.064447
# 12484        12435                   3                0.036388
# 12485        12436                   3                0.040220
# 12486        12437                   3                0.093824
# 12487        12438                   3                0.073523
# 12488        12442                   2                0.112814
# 12489        12444                   2                0.113058
# 12490        12446                   2                0.141031
# 12491        12461                   3                0.058340
# 12492        12473                   1                0.506903
# 12493        12474                   0                1.342193
# 12494        12476                   0                1.518575
# 12495        12484                   1                0.659387
# 12496        12487                   5                0.005010
# 12497        12488                   5                0.008629
# 12498        12491                   5                0.006247
# 12499        12493                   4                0.024409
#
#        Cabin_Temperature  Control_Metric  Days_Since_Inspection  \
# 0                  78.04       71.285324                      5
# 1                  84.54       72.288058                      1
# 2                  78.86       66.362808                      4
# 3                  81.79       74.703737                      2
# 4                  77.16       47.948952                      4
# 5                  78.63       73.336372                      6
# 6                  88.04       62.853236                      6
# 7                  83.48       60.802188                      9
# 8                  78.24       69.234275                     18
# 9                  79.56       57.429353                     19
# 10                 81.15       80.218778                      2
# 11                 77.80       62.807657                      2
# 12                 77.23       68.960802                      3
# 13                 80.78       78.669098                      4
# 14                 81.63       83.546035                      5
# 15                 78.86       85.551504                     20
# 16                 82.08       68.003646                      9
# 17                 80.82       37.830447                      1
# 18                 82.20       61.485871                     21
# 19                 78.37       41.567912                      6
# 20                 81.62       73.245214                      4
# 21                 79.31       74.931632                      8
# 22                 78.21       80.583409                     21
# 23                 78.97       68.003646                      6
# 24                 76.19       47.265269                      5
# 25                 78.07       66.134913                      4
# 26                 90.87       61.622607                      5
# 27                 76.75       70.783956                      5
# 28                 77.03       70.328168                      6
# 29                 79.75       48.131267                     18
# ...                  ...             ...                    ...
# 12470              77.27       65.587967                     10
# 12471              79.17       74.020055                      1
# 12472              79.61       57.155880                      5
# 12473              83.41       80.082042                      5
# 12474              85.91       57.520510                      5
# 12475              84.46       72.971741                      4
# 12476              83.56       74.977211                      5
# 12477              81.74       73.473108                      2
# 12478              78.66       62.716500                      3
# 12479              81.08       45.897903                     22
# 12480              81.21       62.853236                      6
# 12481              80.98       51.002735                     20
# 12482              83.82       90.154968                      4
# 12483              75.34       60.209663                      8
# 12484              78.64       61.257976                     21
# 12485              78.92       82.224248                     12
# 12486              83.65       62.123974                      7
# 12487              78.46       59.161349                     10
# 12488              87.47       58.204193                     19
# 12489              82.53       60.483136                      5
# 12490              78.40       68.322698                      6
# 12491              79.39       52.597995                      1
# 12492              80.12       65.223336                      3
# 12493              81.01       74.703737                      1
# 12494              78.78       65.496809                     22
# 12495              77.80       49.680948                     21
# 12496              79.77       71.194166                     22
# 12497              83.96       91.203282                      5
# 12498              77.38       73.154057                      4
# 12499              84.56       60.665451                      2
#
#        Max_Elevation  Safety_Score  Severity  Total_Safety_Complaints  \
# 0       31335.476824     49.223744         0                       15
# 1       26024.711057     62.465753         0                       20
# 2       39269.053927     63.059361         1                        8
# 3       42771.499200     48.082192         2                       43
# 4       35509.228515     26.484018         1                       18
# 5       29288.448105     43.333333         0                        0
# 6       32342.109345     22.009132         3                        2
# 7       22547.195242     24.703196         0                       34
# 8       45751.983413     54.840183         3                       35
# 9       37933.399001     52.237443         2                       34
# 10      31463.568565     36.666667         3                        3
# 11      22570.030398     48.127854         2                       12
# 12      44697.868740     42.876712         2                        6
# 13      30882.726377     63.652968         1                       34
# 14      18915.509025     26.027397         3                       12
# 15      25083.657909     49.589041         3                        1
# 16      47893.717972     10.867580         3                        1
# 17      35910.200412     38.767123         1                       34
# 18      34354.111221     78.219178         1                       23
# 19      11503.388561     20.228311         1                       12
# 20      39835.718310     52.465753         0                        0
# 21      37435.572795     38.447489         0                       38
# 22      45783.527661     44.840183         3                       12
# 23      45541.236753     43.881279         0                        1
# 24      49288.635507     25.296804         1                       38
# 25      42607.071097     61.826484         1                       41
# 26      32342.313384     59.269406         1                       23
# 27      26538.322263     24.337900         3                        0
# 28      28451.014701     55.022831         1                       43
# 29      39150.672196     65.753425         3                       13
# ...              ...           ...       ...                      ...
# 12470   33945.431301     44.200913        -1                        0
# 12471   40028.326141     39.452055        -1                        1
# 12472    6543.689337     58.858447        -1                       40
# 12473   41343.042916     47.031963        -1                       42
# 12474   29640.209434     37.305936        -1                        3
# 12475   20120.818957     50.776256        -1                        0
# 12476   34924.741830     47.899543        -1                       11
# 12477   24926.767209     33.789954        -1                       12
# 12478   27761.953858     31.232877        -1                       12
# 12479   51246.640854     78.447489        -1                       24
# 12480   22087.486014     22.328767        -1                        6
# 12481   32473.864212     60.456621        -1                       27
# 12482   35862.168288     41.187215        -1                       12
# 12483   35067.705083     14.474886        -1                       12
# 12484   19488.005523     43.789954        -1                       38
# 12485   22172.698351     15.753425        -1                       34
# 12486   52319.166288     17.579909        -1                       12
# 12487   40580.037741     18.721461        -1                        0
# 12488   22753.277323     64.611872        -1                       38
# 12489   22838.312683     26.712329        -1                        1
# 12490   28270.776642     33.972603        -1                        1
# 12491   32253.380602     37.534247        -1                       34
# 12492   37581.571486     57.260274        -1                       41
# 12493   36447.980261     36.438356        -1                        5
# 12494   41139.799202     63.333333        -1                        0
# 12495   48251.586622     68.127854        -1                        3
# 12496   20761.984416     54.840183        -1                       43
# 12497   36676.100601     36.712329        -1                        2
# 12498   24211.359510     38.721461        -1                        6
# 12499   35920.146239     36.073059        -1                        1
#
#        Turbulence_In_gforces  Violations
# 0                   0.272118           3
# 1                   0.423939           2
# 2                   0.322604           3
# 3                   0.337029           1
# 4                   0.541140           2
# 5                   0.432954           1
# 6                   0.314671           0
# 7                   0.548353           2
# 8                   0.335587           0
# 9                   0.465410           1
# 10                  0.452788           2
# 11                  0.329096           4
# 12                  0.159604           3
# 13                  0.232089           3
# 14                  0.362994           2
# 15                  0.270314           2
# 16                  0.309622           3
# 17                  0.600282           1
# 18                  0.338111           2
# 19                  0.687191           1
# 20                  0.221991           1
# 21                  0.326571           2
# 22                  0.249759           0
# 23                  0.338472           2
# 24                  0.594873           3
# 25                  0.423217           1
# 26                  0.331981           3
# 27                  0.267790           1
# 28                  0.512291           0
# 29                  0.638147           1
# ...                      ...         ...
# 12470               0.344963           4
# 12471               0.178356           0
# 12472               0.382828           2
# 12473               0.199633           3
# 12474               0.440888           5
# 12475               0.363715           2
# 12476               0.325850           1
# 12477               0.225958           2
# 12478               0.317556           1
# 12479               0.721450           2
# 12480               0.444855           2
# 12481               0.538977           2
# 12482               0.328735           1
# 12483               0.244350           2
# 12484               0.485244           2
# 12485               0.371649           2
# 12486               0.477671           1
# 12487               0.639590           0
# 12488               0.526355           3
# 12489               0.298082           2
# 12490               0.258775           1
# 12491               0.456034           1
# 12492               0.458919           2
# 12493               0.456034           2
# 12494               0.511209           2
# 12495               0.470819           2
# 12496               0.417087           1
# 12497               0.313950           2
# 12498               0.275003           1
# 12499               0.256250           0
#
# [12500 rows x 12 columns]

# %%
features
# Out:
# ['Days_Since_Inspection',
#  'Total_Safety_Complaints',
#  'Accident_Type_Code',
#  'Violations']

# %%
len(train.columns)
# Out:
# 12

# %%
len(test.columns)
# Out:
# 12

# %%
len(data.columns)
# Out:
# 12

# %%
len(train), len(test), len(data)
# Out:
# (10000, 2500, 12500)

# %%
train = data[data.Severity != -1].reset_index(drop=True)
test = data[data.Severity == -1].reset_index(drop=True)

test_data = [test.loc[:, features].values[:, k] for k in 
             range(test.loc[:, features].values.shape[1])]

# %%
# test.loc[:, features]

# %%
((test.loc[:, features]).values[:, 0])
# Out:
# array([7, 6, 6, ..., 5, 4, 2])

# %%
(test.loc[:, features].values.shape)
# Out:
# (2500, 4)

# %%
# (train.target.values)

# %%
features
# Out:
# ['Days_Since_Inspection',
#  'Total_Safety_Complaints',
#  'Accident_Type_Code',
#  'Violations']

# %%
train
# Out:
#       Accident_ID  Accident_Type_Code  Adverse_Weather_Metric  \
# 0            7570                   1                0.424352
# 1           12128                   1                0.352350
# 2            2181                   6                0.003364
# 3            5946                   2                0.211728
# 4            9054                   2                0.176883
# 5           10947                   1                0.394505
# 6            4717                   3                0.058872
# 7            8008                   3                0.040419
# 8            8179                   1                0.619186
# 9            6324                   0                1.389295
# 10           3789                   1                0.424912
# 11           8946                   2                0.111873
# 12           3629                   2                0.222510
# 13           2451                   6                0.002567
# 14           4028                   2                0.095806
# 15          10493                   2                0.123761
# 16             20                   5                0.011242
# 17           2064                   3                0.066515
# 18           2765                   1                0.462514
# 19           2938                   1                0.159784
# 20          10309                   1                0.538862
# 21           3918                   1                0.508486
# 22           4830                   3                0.083992
# 23           6630                   0                1.664864
# 24          11434                   4                0.032437
# 25          10987                   5                0.010607
# 26           8830                   6                0.003022
# 27           2237                   3                0.048626
# 28           4196                   6                0.002916
# 29           4755                   2                0.194870
# ...           ...                 ...                     ...
# 9970         2639                   1                0.532044
# 9971        10295                   2                0.195685
# 9972         7482                   5                0.006656
# 9973        11730                   3                0.042284
# 9974         6540                   1                0.374260
# 9975         2252                   3                0.065012
# 9976         2180                   4                0.008689
# 9977         5335                   1                0.413995
# 9978         4986                   0                0.972403
# 9979         3769                   3                0.043585
# 9980         4486                   2                0.171256
# 9981         7050                   4                0.020208
# 9982         7875                   3                0.114421
# 9983        11977                   6                0.004191
# 9984         8835                   3                0.053177
# 9985         8914                   3                0.060404
# 9986         4875                   0                0.890282
# 9987         4694                   2                0.130517
# 9988         7975                   2                0.153106
# 9989         3380                   2                0.098919
# 9990          193                   4                0.025955
# 9991        12323                   3                0.067987
# 9992         9869                   0                1.156478
# 9993         5842                   3                0.071406
# 9994        11039                   3                0.053848
# 9995        11493                   4                0.026150
# 9996          305                   3                0.074898
# 9997          612                   2                0.168173
# 9998         4963                   4                0.026381
# 9999         9387                   4                0.017036
#
#       Cabin_Temperature  Control_Metric  Days_Since_Inspection  Max_Elevation  \
# 0                 78.04       71.285324                      5   31335.476824
# 1                 84.54       72.288058                      1   26024.711057
# 2                 78.86       66.362808                      4   39269.053927
# 3                 81.79       74.703737                      2   42771.499200
# 4                 77.16       47.948952                      4   35509.228515
# 5                 78.63       73.336372                      6   29288.448105
# 6                 88.04       62.853236                      6   32342.109345
# 7                 83.48       60.802188                      9   22547.195242
# 8                 78.24       69.234275                     18   45751.983413
# 9                 79.56       57.429353                     19   37933.399001
# 10                81.15       80.218778                      2   31463.568565
# 11                77.80       62.807657                      2   22570.030398
# 12                77.23       68.960802                      3   44697.868740
# 13                80.78       78.669098                      4   30882.726377
# 14                81.63       83.546035                      5   18915.509025
# 15                78.86       85.551504                     20   25083.657909
# 16                82.08       68.003646                      9   47893.717972
# 17                80.82       37.830447                      1   35910.200412
# 18                82.20       61.485871                     21   34354.111221
# 19                78.37       41.567912                      6   11503.388561
# 20                81.62       73.245214                      4   39835.718310
# 21                79.31       74.931632                      8   37435.572795
# 22                78.21       80.583409                     21   45783.527661
# 23                78.97       68.003646                      6   45541.236753
# 24                76.19       47.265269                      5   49288.635507
# 25                78.07       66.134913                      4   42607.071097
# 26                90.87       61.622607                      5   32342.313384
# 27                76.75       70.783956                      5   26538.322263
# 28                77.03       70.328168                      6   28451.014701
# 29                79.75       48.131267                     18   39150.672196
# ...                 ...             ...                    ...            ...
# 9970              78.51       72.880583                      5   39506.691424
# 9971              76.89       75.706472                     22   39092.058018
# 9972              80.78       77.438469                     21   27827.851427
# 9973              80.37       62.944394                      3   22817.294950
# 9974              81.39       49.680948                      7   27654.285015
# 9975              79.21       69.097539                      2   35553.185789
# 9976              77.78       64.357338                      5   12660.980282
# 9977              87.00       48.906108                      4   30701.490358
# 9978              86.57       54.740201                      3   26432.644879
# 9979              77.41       71.057429                      4   23734.751306
# 9980              79.14       67.000912                      6   34176.122716
# 9981              78.50       61.713765                      7   29541.265285
# 9982              78.54       78.076572                      5   55360.356917
# 9983              82.45       72.835005                      9   42627.763175
# 9984              82.31       62.260711                      9   29267.164873
# 9985              80.12       34.867821                     22   32628.399491
# 9986              78.13       47.994531                      7   24605.471319
# 9987              81.10       68.778487                      1   26335.223800
# 9988              80.44       67.684594                     17   30706.354766
# 9989              79.03       37.830447                     10   19797.321790
# 9990              83.21       76.481313                      3   38728.486502
# 9991              81.02       73.837739                     22   37351.507472
# 9992              75.89       74.703737                      3   31531.796196
# 9993              79.14       69.781222                      7   39202.492521
# 9994              79.33       57.976299                     22   29224.022983
# 9995              78.64       63.445761                     21   38537.363408
# 9996              79.77       62.169553                      1   40846.916900
# 9997              80.37       69.598906                      8   33771.996300
# 9998              76.92       39.835916                     21   39820.419251
# 9999              77.46       45.487694                      4   26005.322987
#
#       Safety_Score  Severity  Total_Safety_Complaints  Turbulence_In_gforces  \
# 0        49.223744         0                       15               0.272118
# 1        62.465753         0                       20               0.423939
# 2        63.059361         1                        8               0.322604
# 3        48.082192         2                       43               0.337029
# 4        26.484018         1                       18               0.541140
# 5        43.333333         0                        0               0.432954
# 6        22.009132         3                        2               0.314671
# 7        24.703196         0                       34               0.548353
# 8        54.840183         3                       35               0.335587
# 9        52.237443         2                       34               0.465410
# 10       36.666667         3                        3               0.452788
# 11       48.127854         2                       12               0.329096
# 12       42.876712         2                        6               0.159604
# 13       63.652968         1                       34               0.232089
# 14       26.027397         3                       12               0.362994
# 15       49.589041         3                        1               0.270314
# 16       10.867580         3                        1               0.309622
# 17       38.767123         1                       34               0.600282
# 18       78.219178         1                       23               0.338111
# 19       20.228311         1                       12               0.687191
# 20       52.465753         0                        0               0.221991
# 21       38.447489         0                       38               0.326571
# 22       44.840183         3                       12               0.249759
# 23       43.881279         0                        1               0.338472
# 24       25.296804         1                       38               0.594873
# 25       61.826484         1                       41               0.423217
# 26       59.269406         1                       23               0.331981
# 27       24.337900         3                        0               0.267790
# 28       55.022831         1                       43               0.512291
# 29       65.753425         3                       13               0.638147
# ...            ...       ...                      ...                    ...
# 9970     47.853881         0                       41               0.363715
# 9971     54.474886         2                       23               0.384992
# 9972     57.168950         2                       38               0.309983
# 9973     32.420091         3                       38               0.350733
# 9974     29.817352         0                       23               0.696568
# 9975     33.835616         3                       40               0.241465
# 9976     49.269406         0                       40               0.409875
# 9977     27.625571         1                       41               0.438003
# 9978     42.420091         0                       42               0.362633
# 9979     50.593607         0                       15               0.205042
# 9980     33.242009         2                        0               0.387516
# 9981     40.913242         0                       38               0.512291
# 9982     23.607306         3                       41               0.367682
# 9983     13.698630         3                        1               0.217303
# 9984     34.155251         0                       23               0.427184
# 9985     42.968037         1                        0               0.619395
# 9986     28.858447         0                       23               0.414563
# 9987     49.817352         2                       34               0.343160
# 9988     60.228311         2                       41               0.294476
# 9989     20.867580         0                        0               0.571432
# 9990     66.255708         0                        0               0.224876
# 9991     52.465753         3                        0               0.369846
# 9992     32.146119         3                       12               0.245071
# 9993     31.095890         2                       40               0.317195
# 9994     41.552511         3                        1               0.503996
# 9995     56.118721         2                        1               0.482359
# 9996     40.365297         3                       41               0.421775
# 9997     27.853881         2                        1               0.318277
# 9998     56.210046         0                        0               0.598118
# 9999     50.000000         3                       23               0.382467
#
#       Violations
# 0              3
# 1              2
# 2              3
# 3              1
# 4              2
# 5              1
# 6              0
# 7              2
# 8              0
# 9              1
# 10             2
# 11             4
# 12             3
# 13             3
# 14             2
# 15             2
# 16             3
# 17             1
# 18             2
# 19             1
# 20             1
# 21             2
# 22             0
# 23             2
# 24             3
# 25             1
# 26             3
# 27             1
# 28             0
# 29             1
# ...          ...
# 9970           1
# 9971           3
# 9972           0
# 9973           1
# 9974           3
# 9975           2
# 9976           1
# 9977           2
# 9978           2
# 9979           3
# 9980           3
# 9981           2
# 9982           2
# 9983           4
# 9984           3
# 9985           2
# 9986           1
# 9987           0
# 9988           1
# 9989           2
# 9990           2
# 9991           2
# 9992           1
# 9993           1
# 9994           2
# 9995           2
# 9996           2
# 9997           3
# 9998           2
# 9999           2
#
# [10000 rows x 12 columns]

# %%
test.index.values
# Out:
# array([   0,    1,    2, ..., 2497, 2498, 2499])

# %%
train.loc[:, features]#.values[:, 0]
# Out:
#       Days_Since_Inspection  Total_Safety_Complaints  Accident_Type_Code  \
# 0                         5                       15                   1
# 1                         1                       20                   1
# 2                         4                        8                   6
# 3                         2                       43                   2
# 4                         4                       18                   2
# 5                         6                        0                   1
# 6                         6                        2                   3
# 7                         9                       34                   3
# 8                        18                       35                   1
# 9                        19                       34                   0
# 10                        2                        3                   1
# 11                        2                       12                   2
# 12                        3                        6                   2
# 13                        4                       34                   6
# 14                        5                       12                   2
# 15                       20                        1                   2
# 16                        9                        1                   5
# 17                        1                       34                   3
# 18                       21                       23                   1
# 19                        6                       12                   1
# 20                        4                        0                   1
# 21                        8                       38                   1
# 22                       21                       12                   3
# 23                        6                        1                   0
# 24                        5                       38                   4
# 25                        4                       41                   5
# 26                        5                       23                   6
# 27                        5                        0                   3
# 28                        6                       43                   6
# 29                       18                       13                   2
# ...                     ...                      ...                 ...
# 9970                      5                       41                   1
# 9971                     22                       23                   2
# 9972                     21                       38                   5
# 9973                      3                       38                   3
# 9974                      7                       23                   1
# 9975                      2                       40                   3
# 9976                      5                       40                   4
# 9977                      4                       41                   1
# 9978                      3                       42                   0
# 9979                      4                       15                   3
# 9980                      6                        0                   2
# 9981                      7                       38                   4
# 9982                      5                       41                   3
# 9983                      9                        1                   6
# 9984                      9                       23                   3
# 9985                     22                        0                   3
# 9986                      7                       23                   0
# 9987                      1                       34                   2
# 9988                     17                       41                   2
# 9989                     10                        0                   2
# 9990                      3                        0                   4
# 9991                     22                        0                   3
# 9992                      3                       12                   0
# 9993                      7                       40                   3
# 9994                     22                        1                   3
# 9995                     21                        1                   4
# 9996                      1                       41                   3
# 9997                      8                        1                   2
# 9998                     21                        0                   4
# 9999                      4                       23                   4
#
#       Violations
# 0              3
# 1              2
# 2              3
# 3              1
# 4              2
# 5              1
# 6              0
# 7              2
# 8              0
# 9              1
# 10             2
# 11             4
# 12             3
# 13             3
# 14             2
# 15             2
# 16             3
# 17             1
# 18             2
# 19             1
# 20             1
# 21             2
# 22             0
# 23             2
# 24             3
# 25             1
# 26             3
# 27             1
# 28             0
# 29             1
# ...          ...
# 9970           1
# 9971           3
# 9972           0
# 9973           1
# 9974           3
# 9975           2
# 9976           1
# 9977           2
# 9978           2
# 9979           3
# 9980           3
# 9981           2
# 9982           2
# 9983           4
# 9984           3
# 9985           2
# 9986           1
# 9987           0
# 9988           1
# 9989           2
# 9990           2
# 9991           2
# 9992           1
# 9993           1
# 9994           2
# 9995           2
# 9996           2
# 9997           3
# 9998           2
# 9999           2
#
# [10000 rows x 4 columns]

# %%
cols = ['Accident_Type_Code', 'Adverse_Weather_Metric',
       'Cabin_Temperature', 'Control_Metric', 'Days_Since_Inspection',
       'Max_Elevation', 'Safety_Score', 'Severity', 'Total_Safety_Complaints',
       'Turbulence_In_gforces', 'Violations']

# %%
cols, len(cols)

# %%
oof_preds = np.zeros(len(train))
test_preds = np.zeros(len(test))

skf = StratifiedKFold(n_splits=5)
count = 0
for train_index, test_index in skf.split(train, train.Severity.values):
    X_train, X_test = train.iloc[train_index, :], train.iloc[test_index, :]
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train, y_test = X_train.Severity.values, X_test.Severity.values
    
    model = create_model(data, features)
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                  metrics = [auc])
    
    X_train = [X_train.loc[:, features].values[:, k] for k in range(X_train.loc[:, features].values.shape[1])]
    
    X_test = [X_test.loc[:, features].values[:, k] for k in range(X_test.loc[:, features].values.shape[1])]
    
    
    es = callbacks.EarlyStopping(monitor='val_auc', min_delta=0.001,
                                 patience=5, verbose=1, mode='max',
                                baseline=None, restore_best_weights=True)
    rlr = callbacks.ReduceLROnPlateau(monitor='val_auc', factor=0.5,
                                    patience=3, min_lr=1e-06, mode='max',
                                    verbose=1)
    
    model.fit(X_train, utils.to_categorical(y_train, num_classes=4), 
             validation_data=(X_test, utils.to_categorical(y_test, num_classes=4)),
             verbose=1, batch_size=1024, callbacks=[es, rlr],
             epochs = 20)
    
    vaild_fold_preds = model.predict(X_test)[:, 1]
    test_fold_preds = model.predict(test_data)[:, 1]
    print(model.predict(test_data), len(model.predict(test_data)))
    
    oof_preds[test_index] = vaild_fold_preds.ravel()
    
    test_preds += test_fold_preds.ravel()
    
#     print(metrics.roc_auc_score(y_test, vaild_fold_preds))
    K.clear_session()
#     count +=1
#     if count==3:
#         break
# Out:
# Train on 7999 samples, validate on 2001 samples
# Epoch 1/20
# 7999/7999 [==============================] - 1s 114us/sample - loss: 1.8032 - auc: 0.5000 - val_loss: 1.3729 - val_auc: 0.5000
# Epoch 2/20
# 7999/7999 [==============================] - 0s 21us/sample - loss: 1.6264 - auc: 0.5000 - val_loss: 1.3652 - val_auc: 0.5000
# Epoch 3/20
# 7999/7999 [==============================] - 0s 20us/sample - loss: 1.5353 - auc: 0.5000 - val_loss: 1.3620 - val_auc: 0.5000
# Epoch 4/20
# 7168/7999 [=========================>....] - ETA: 0s - loss: 1.4527 - auc: 0.5000
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 7999/7999 [==============================] - 0s 28us/sample - loss: 1.4542 - auc: 0.5000 - val_loss: 1.3604 - val_auc: 0.5000
# Epoch 5/20
# 7999/7999 [==============================] - 0s 20us/sample - loss: 1.4139 - auc: 0.5000 - val_loss: 1.3598 - val_auc: 0.5000
# Epoch 6/20
# 7168/7999 [=========================>....] - ETA: 0s - loss: 1.4074 - auc: 0.5000Restoring model weights from the end of the best epoch.
# 7999/7999 [==============================] - 0s 35us/sample - loss: 1.4051 - auc: 0.5000 - val_loss: 1.3596 - val_auc: 0.5000
# Epoch 00006: early stopping
# [[0.25566018 0.22219132 0.25140297 0.27074552]
#  [0.2546141  0.22592756 0.25912237 0.260336  ]
#  [0.25654906 0.22128236 0.25878006 0.26338857]
#  ...
#  [0.25504372 0.22373827 0.25664237 0.2645757 ]
#  [0.2533656  0.22583291 0.25462347 0.26617804]
#  [0.2553205  0.22166488 0.25469494 0.26831973]] 2500
# Train on 7999 samples, validate on 2001 samples
# Epoch 1/20
# 7999/7999 [==============================] - 1s 122us/sample - loss: 1.7938 - auc: 0.5000 - val_loss: 1.3740 - val_auc: 0.5000
# Epoch 2/20
# 7999/7999 [==============================] - 0s 22us/sample - loss: 1.5837 - auc: 0.5000 - val_loss: 1.3675 - val_auc: 0.5000
# Epoch 3/20
# 7999/7999 [==============================] - 0s 20us/sample - loss: 1.4926 - auc: 0.5000 - val_loss: 1.3641 - val_auc: 0.5000
# Epoch 4/20
# 7168/7999 [=========================>....] - ETA: 0s - loss: 1.4549 - auc: 0.5000
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 7999/7999 [==============================] - 0s 31us/sample - loss: 1.4559 - auc: 0.5000 - val_loss: 1.3624 - val_auc: 0.5000
# Epoch 5/20
# 7999/7999 [==============================] - 0s 34us/sample - loss: 1.4072 - auc: 0.5000 - val_loss: 1.3625 - val_auc: 0.5000
# Epoch 6/20
# 7168/7999 [=========================>....] - ETA: 0s - loss: 1.4013 - auc: 0.5000Restoring model weights from the end of the best epoch.
# 7999/7999 [==============================] - 0s 47us/sample - loss: 1.3993 - auc: 0.5000 - val_loss: 1.3627 - val_auc: 0.5000
# Epoch 00006: early stopping
# [[0.25337282 0.2261414  0.25836167 0.26212415]
#  [0.25631928 0.22742812 0.25895387 0.25729877]
#  [0.2573198  0.22584607 0.25951716 0.25731698]
#  ...
#  [0.2550468  0.22605334 0.25965673 0.25924313]
#  [0.25463423 0.22632946 0.26120803 0.2578283 ]
#  [0.25620386 0.22665294 0.25826496 0.2588783 ]] 2500
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/20
# 8000/8000 [==============================] - 1s 110us/sample - loss: 1.7708 - auc: 0.5000 - val_loss: 1.3715 - val_auc: 0.5000
# Epoch 2/20
# 8000/8000 [==============================] - 0s 23us/sample - loss: 1.5761 - auc: 0.5000 - val_loss: 1.3646 - val_auc: 0.5000
# Epoch 3/20
# 8000/8000 [==============================] - 0s 20us/sample - loss: 1.4924 - auc: 0.5000 - val_loss: 1.3616 - val_auc: 0.5000
# Epoch 4/20
# 7168/8000 [=========================>....] - ETA: 0s - loss: 1.4429 - auc: 0.5000
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 8000/8000 [==============================] - 0s 29us/sample - loss: 1.4387 - auc: 0.5000 - val_loss: 1.3594 - val_auc: 0.5000
# Epoch 5/20
# 8000/8000 [==============================] - 0s 20us/sample - loss: 1.3878 - auc: 0.5000 - val_loss: 1.3587 - val_auc: 0.5000
# Epoch 6/20
# 7168/8000 [=========================>....] - ETA: 0s - loss: 1.3733 - auc: 0.5000Restoring model weights from the end of the best epoch.
# 8000/8000 [==============================] - 0s 34us/sample - loss: 1.3723 - auc: 0.5000 - val_loss: 1.3581 - val_auc: 0.5000
# Epoch 00006: early stopping
# [[0.24035063 0.22507726 0.25913095 0.27544123]
#  [0.243659   0.22691439 0.26396698 0.2654597 ]
#  [0.24280123 0.22672479 0.26490483 0.26556918]
#  ...
#  [0.24152206 0.22667423 0.2648184  0.26698527]
#  [0.24076222 0.22677185 0.2636173  0.26884863]
#  [0.24043676 0.22509834 0.26200938 0.27245554]] 2500
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/20
# 8000/8000 [==============================] - 1s 115us/sample - loss: 1.7231 - auc: 0.5000 - val_loss: 1.3719 - val_auc: 0.5000
# Epoch 2/20
# 8000/8000 [==============================] - 0s 23us/sample - loss: 1.5391 - auc: 0.5000 - val_loss: 1.3664 - val_auc: 0.5000
# Epoch 3/20
# 8000/8000 [==============================] - 0s 21us/sample - loss: 1.4840 - auc: 0.5000 - val_loss: 1.3634 - val_auc: 0.5000
# Epoch 4/20
# 7168/8000 [=========================>....] - ETA: 0s - loss: 1.4065 - auc: 0.5000
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 8000/8000 [==============================] - 0s 29us/sample - loss: 1.4063 - auc: 0.5000 - val_loss: 1.3607 - val_auc: 0.5000
# Epoch 5/20
# 8000/8000 [==============================] - 0s 25us/sample - loss: 1.3783 - auc: 0.5000 - val_loss: 1.3601 - val_auc: 0.5000
# Epoch 6/20
# 7168/8000 [=========================>....] - ETA: 0s - loss: 1.3734 - auc: 0.5000Restoring model weights from the end of the best epoch.
# 8000/8000 [==============================] - 0s 36us/sample - loss: 1.3745 - auc: 0.5000 - val_loss: 1.3596 - val_auc: 0.5000
# Epoch 00006: early stopping
# [[0.23920439 0.22853565 0.26323757 0.26902238]
#  [0.24262102 0.22764467 0.2671841  0.26255023]
#  [0.24615745 0.22596568 0.26556322 0.26231372]
#  ...
#  [0.24184434 0.22624162 0.2670747  0.2648394 ]
#  [0.24051264 0.22306997 0.2697916  0.26662576]
#  [0.24625324 0.2230254  0.26431087 0.2664105 ]] 2500
# Train on 8002 samples, validate on 1998 samples
# Epoch 1/20
# 8002/8002 [==============================] - 1s 117us/sample - loss: 1.7772 - auc: 0.5000 - val_loss: 1.3735 - val_auc: 0.5000
# Epoch 2/20
# 8002/8002 [==============================] - 0s 21us/sample - loss: 1.5276 - auc: 0.5000 - val_loss: 1.3675 - val_auc: 0.5000
# Epoch 3/20
# 8002/8002 [==============================] - 0s 21us/sample - loss: 1.4796 - auc: 0.5000 - val_loss: 1.3652 - val_auc: 0.5000
# Epoch 4/20
# 7168/8002 [=========================>....] - ETA: 0s - loss: 1.4078 - auc: 0.5000
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 8002/8002 [==============================] - 0s 30us/sample - loss: 1.4051 - auc: 0.5000 - val_loss: 1.3643 - val_auc: 0.5000
# Epoch 5/20
# 8002/8002 [==============================] - 0s 19us/sample - loss: 1.3921 - auc: 0.5000 - val_loss: 1.3648 - val_auc: 0.5000
# Epoch 6/20
# 7168/8002 [=========================>....] - ETA: 0s - loss: 1.3690 - auc: 0.5000Restoring model weights from the end of the best epoch.
# 8002/8002 [==============================] - 0s 36us/sample - loss: 1.3655 - auc: 0.5000 - val_loss: 1.3647 - val_auc: 0.5000
# Epoch 00006: early stopping
# [[0.25384557 0.22845316 0.2532729  0.26442832]
#  [0.2584007  0.22674917 0.2549974  0.25985268]
#  [0.25725457 0.22579207 0.25735858 0.25959486]
#  ...
#  [0.25482368 0.22623704 0.25917676 0.25976253]
#  [0.2566284  0.22612321 0.25455475 0.26269364]
#  [0.25932223 0.22619459 0.25479332 0.2596899 ]] 2500

# %%
print('Overall AUC = {}'.format(metrics.f1_score(train.Severity.values,
                                                     oof_preds)))

# %%
test_preds/5

# %%
test_preds /= 5
test_ids = test.Accident_ID.values
print("saving submisssion file")

submission = pd.DataFrame.from_dict({'Accident_ID': test_ids,
                                    'Severity': test_preds})

submission.to_csv('submission.csv', index=False)
